# %%
import pandas as pd 
import requests 
from bs4 import BeautifulSoup
from selenium import webdriver

url = 'https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=053800'
driver = webdriver.Chrome('C:\chromedriver.exe')

# %%
driver.get(url)

table = BeautifulSoup(driver.page_source,'html.parser')

table_tr = money_table.find_all('tr') 

test_tr = pd.read_html(driver.page_source)

# %%
finance_table = test_tr[14]
finance_table
# Out:
#         주요재무정보        연간연간컨센서스보기                                      \
#         주요재무정보 2017/12  (IFRS연결) 2018/12  (IFRS연결) 2019/12  (IFRS연결)
# 0          매출액           1503.00           1598.00           1670.00
# 1         영업이익            167.00            177.00            184.00
# 2   영업이익(발표기준)            167.00            177.00            184.00
# 3     세전계속사업이익            189.00            254.00            218.00
# 4        당기순이익            163.00            228.00            191.00
# 5    당기순이익(지배)            163.00            228.00            191.00
# 6   당기순이익(비지배)               NaN               NaN               NaN
# 7         자산총계           2236.00           2448.00           2602.00
# 8         부채총계            397.00            504.00            545.00
# 9         자본총계           1839.00           1944.00           2057.00
# 10    자본총계(지배)           1839.00           1944.00           2057.00
# 11   자본총계(비지배)               NaN               NaN               NaN
# ...

# %%
finance_extract =finance_table.iloc[[0,1,4,7,8,9,19,20],:].dropna(axis=1)

# %%
finance_extract.head()
# Out:
#   주요재무정보        연간연간컨센서스보기                                      \
#   주요재무정보 2017/12  (IFRS연결) 2018/12  (IFRS연결) 2019/12  (IFRS연결)
# 0    매출액            1503.0            1598.0            1670.0
# 1   영업이익             167.0             177.0             184.0
# 4  당기순이익             163.0             228.0             191.0
# 7   자산총계            2236.0            2448.0            2602.0
# 8   부채총계             397.0             504.0             545.0
#
#          분기분기컨센서스보기
#   2019/09  (IFRS연결) 2019/12  (IFRS연결) 2020/03  (IFRS연결)
# 0             431.0             429.0             404.0
# 1              54.0              49.0              30.0
# 4              49.0              52.0              33.0
# 7            2481.0            2602.0            2668.0
# 8             476.0             545.0             647.0

# %%
# %%write
