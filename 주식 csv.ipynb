# %%
#삼성전자
import pandas as pd 
import requests 

html = requests.get('https://finance.naver.com/item/sise_day.nhn?code=005930&page=1') 

table = pd.read_html(html.text)

# %%
for i in range(50):
    html = requests.get('https://finance.naver.com/item/sise_day.nhn?code=005930&page={}'.format(i + 1))
    table = pd.read_html(html.text)
    if i == 0:
        data = table[0].dropna().reset_index(drop = True)
    else:
        data1 = table[0].dropna().reset_index(drop = True)
        data = pd.concat([data, data1])

samsung_data = data.reset_index(drop = True)
samsung_data
# Out:
#              날짜       종가     전일비       시가       고가       저가         거래량
# 0    2020.07.30  59900.0   900.0  59700.0  60100.0  59400.0   5514498.0
# 1    2020.07.29  59000.0   400.0  60300.0  60400.0  58600.0  36476611.0
# 2    2020.07.28  58600.0  3000.0  57000.0  58800.0  56400.0  48431566.0
# 3    2020.07.27  55600.0  1400.0  54300.0  55700.0  54300.0  21054421.0
# 4    2020.07.24  54200.0   100.0  54000.0  54400.0  53700.0  10994535.0
# ..          ...      ...     ...      ...      ...      ...         ...
# 495  2018.07.26  46900.0   750.0  46100.0  47000.0  46000.0   7374946.0
# 496  2018.07.25  46150.0     0.0  46250.0  46550.0  45900.0   7222471.0
# 497  2018.07.24  46150.0   350.0  46350.0  46600.0  45950.0   8261363.0
# 498  2018.07.23  46500.0   950.0  47100.0  47200.0  46150.0  10823782.0
# 499  2018.07.20  47450.0   550.0  47000.0  47600.0  46700.0  10474547.0
#
# [500 rows x 7 columns]

# %%
#csv 파일 전환
samsung_data.to_csv('samsung.csv' ,encoding='cp949')

# %%
#멀티캠퍼스
import pandas as pd 
import requests 

html = requests.get('https://finance.naver.com/item/sise_day.nhn?code=067280&page=1') 

table = pd.read_html(html.text)

# %%
for i in range(50):
    html = requests.get('https://finance.naver.com/item/sise_day.nhn?code=067280&page={}'.format(i + 1))
    table = pd.read_html(html.text)
    if i == 0:
        data = table[0].dropna().reset_index(drop = True)
    else:
        data1 = table[0].dropna().reset_index(drop = True)
        data = pd.concat([data, data1])

multicampus_data = data.reset_index(drop = True)
multicampus_data
# Out:
#              날짜       종가    전일비       시가       고가       저가      거래량
# 0    2020.07.30  29600.0  100.0  29650.0  29700.0  29550.0    656.0
# 1    2020.07.29  29700.0    0.0  29700.0  29750.0  29450.0   8983.0
# 2    2020.07.28  29700.0    0.0  29800.0  30300.0  29450.0  14047.0
# 3    2020.07.27  29700.0  750.0  30600.0  30600.0  29700.0  13598.0
# 4    2020.07.24  30450.0  150.0  29950.0  30500.0  29950.0   5064.0
# ..          ...      ...    ...      ...      ...      ...      ...
# 495  2018.07.26  34900.0  300.0  34900.0  34900.0  34200.0   4335.0
# 496  2018.07.25  34600.0    0.0  34600.0  35200.0  34400.0    902.0
# 497  2018.07.24  34600.0  800.0  35800.0  35800.0  34600.0   2579.0
# 498  2018.07.23  35400.0  100.0  35500.0  35500.0  34850.0   3629.0
# 499  2018.07.20  35500.0    0.0  35500.0  36000.0  35300.0   3096.0
#
# [500 rows x 7 columns]

# %%
multicampus_data.to_csv('multicampus.csv', encoding='cp949')

# %%
#씨젠
import pandas as pd 
import requests 

html = requests.get('https://finance.naver.com/item/sise_day.nhn?code=096530&page=1') 

table = pd.read_html(html.text)

# %%
for i in range(50):
    html = requests.get('https://finance.naver.com/item/sise_day.nhn?code=096530&page={}'.format(i + 1))
    table = pd.read_html(html.text)
    if i == 0:
        data = table[0].dropna().reset_index(drop = True)
    else:
        data1 = table[0].dropna().reset_index(drop = True)
        data = pd.concat([data, data1])

seegene_data = data.reset_index(drop = True)
seegene_data
# Out:
#              날짜        종가      전일비        시가        고가        저가        거래량
# 0    2020.07.30  244500.0   6300.0  239000.0  247000.0  237100.0   782472.0
# 1    2020.07.29  238200.0  21000.0  220500.0  245200.0  219000.0  5278074.0
# 2    2020.07.28  217200.0   1200.0  219400.0  220200.0  214000.0  1078198.0
# 3    2020.07.27  216000.0   7500.0  214100.0  225700.0  212600.0  2803278.0
# 4    2020.07.24  208500.0   2400.0  213100.0  216600.0  204400.0  2365337.0
# ..          ...       ...      ...       ...       ...       ...        ...
# 495  2018.07.26   25450.0    400.0   24800.0   25850.0   24800.0   128565.0
# 496  2018.07.25   25050.0   1700.0   26750.0   27000.0   24600.0   295588.0
# 497  2018.07.24   26750.0    550.0   26700.0   27500.0   26600.0   112413.0
# 498  2018.07.23   27300.0    450.0   27750.0   27950.0   27300.0    88312.0
# 499  2018.07.20   27750.0    450.0   28800.0   28900.0   27350.0   145326.0
#
# [500 rows x 7 columns]

# %%
seegene_data.to_csv('seegene.csv', encoding='cp949')

# %%
#카카오
import pandas as pd 
import requests 

html = requests.get('https://finance.naver.com/item/sise_day.nhn?code=035720&page=1') 

table = pd.read_html(html.text)

# %%
for i in range(50):
    html = requests.get('https://finance.naver.com/item/sise_day.nhn?code=035720&page={}'.format(i + 1))
    table = pd.read_html(html.text)
    if i == 0:
        data = table[0].dropna().reset_index(drop = True)
    else:
        data1 = table[0].dropna().reset_index(drop = True)
        data = pd.concat([data, data1])

kakao_data = data.reset_index(drop = True)
kakao_data
# Out:
#              날짜        종가     전일비        시가        고가        저가       거래량
# 0    2020.07.30  334000.0  2500.0  336000.0  337000.0  333000.0  158517.0
# 1    2020.07.29  331500.0  2000.0  329000.0  333000.0  325000.0  618435.0
# 2    2020.07.28  329500.0  3000.0  332000.0  336000.0  328500.0  873063.0
# 3    2020.07.27  326500.0  2000.0  321000.0  329500.0  320500.0  603322.0
# 4    2020.07.24  324500.0  5000.0  325000.0  333000.0  322000.0  907643.0
# ..          ...       ...     ...       ...       ...       ...       ...
# 495  2018.07.26  117500.0   500.0  118000.0  118500.0  116000.0  262125.0
# 496  2018.07.25  118000.0  1000.0  117500.0  118000.0  116000.0  310394.0
# 497  2018.07.24  117000.0  1500.0  115500.0  118000.0  115000.0  502533.0
# 498  2018.07.23  115500.0   500.0  115000.0  117000.0  113500.0  346894.0
# 499  2018.07.20  115000.0  1000.0  114000.0  115500.0  113000.0  184967.0
#
# [500 rows x 7 columns]

# %%
kakao_data.to_csv('kakao.csv',encoding='cp949')

# %%
#네이버
import pandas as pd 
import requests 

html = requests.get('https://finance.naver.com/item/sise_day.nhn?code=035420&page=1') 

table = pd.read_html(html.text)

# %%
for i in range(50):
    html = requests.get('https://finance.naver.com/item/sise_day.nhn?code=035420&page={}'.format(i + 1))
    table = pd.read_html(html.text)
    if i == 0:
        data = table[0].dropna().reset_index(drop = True)
    else:
        data1 = table[0].dropna().reset_index(drop = True)
        data = pd.concat([data, data1])

naver_data = data.reset_index(drop = True)
naver_data
# Out:
#              날짜        종가      전일비        시가        고가        저가        거래량
# 0    2020.07.30  292500.0    500.0  296000.0  297500.0  291000.0   447945.0
# 1    2020.07.29  292000.0   4000.0  286000.0  292000.0  283000.0   964066.0
# 2    2020.07.28  288000.0   3500.0  289500.0  292000.0  284000.0   978238.0
# 3    2020.07.27  284500.0   3500.0  281000.0  287500.0  276500.0   691075.0
# 4    2020.07.24  281000.0   3000.0  281000.0  290500.0  278500.0  1233584.0
# ..          ...       ...      ...       ...       ...       ...        ...
# 495  2018.07.26  751000.0   5000.0  752000.0  761000.0  716000.0   224252.0
# 496  2018.07.25  746000.0   1000.0  759000.0  759000.0  742000.0    94581.0
# 497  2018.07.24  745000.0  29000.0  775000.0  776000.0  742000.0    84503.0
# 498  2018.07.23  774000.0   4000.0  771000.0  777000.0  765000.0    81430.0
# 499  2018.07.20  770000.0   5000.0  765000.0  772000.0  755000.0    50449.0
#
# [500 rows x 7 columns]

# %%
naver_data1= naver_data.to_csv('naver.csv')

# %%
a = naver_data['종가'].plot()

# %%
type(naver_data)
# Out:
# pandas.core.frame.DataFrame

# %%
import datetime

k= pd.DataFrame(pd.to_datetime(naver_data['날짜']))
print(k)
# Out:
#             날짜
# 0   2020-07-30
# 1   2020-07-29
# 2   2020-07-28
# 3   2020-07-27
# 4   2020-07-24
# ..         ...
# 495 2018-07-26
# 496 2018-07-25
# 497 2018-07-24
# 498 2018-07-23
# 499 2018-07-20
#
# [500 rows x 1 columns]

# %%
k['year'] =pd.DatetimeIndex(k['날짜']).year

# %%
k.head(40)
# Out:
#            날짜  year
# 0  2020-07-30  2020
# 1  2020-07-29  2020
# 2  2020-07-28  2020
# 3  2020-07-27  2020
# 4  2020-07-24  2020
# 5  2020-07-23  2020
# 6  2020-07-22  2020
# 7  2020-07-21  2020
# 8  2020-07-20  2020
# 9  2020-07-17  2020
# 10 2020-07-16  2020
# 11 2020-07-15  2020
# 12 2020-07-14  2020
# 13 2020-07-13  2020
# 14 2020-07-10  2020
# 15 2020-07-09  2020
# 16 2020-07-08  2020
# 17 2020-07-07  2020
# 18 2020-07-06  2020
# 19 2020-07-03  2020
# 20 2020-07-02  2020
# 21 2020-07-01  2020
# 22 2020-06-30  2020
# 23 2020-06-29  2020
# 24 2020-06-26  2020
# 25 2020-06-25  2020
# 26 2020-06-24  2020
# 27 2020-06-23  2020
# 28 2020-06-22  2020
# 29 2020-06-19  2020
# 30 2020-06-18  2020
# 31 2020-06-17  2020
# 32 2020-06-16  2020
# 33 2020-06-15  2020
# 34 2020-06-12  2020
# 35 2020-06-11  2020
# 36 2020-06-10  2020
# 37 2020-06-09  2020
# 38 2020-06-08  2020
# 39 2020-06-05  2020
